# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

# scan 2D MOT X starting around 1.371. Scanning in HH configuration first to see if maximum shifted before making a gradient. 
#np.tile(np.arange(1, 1.65, 0.05), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 28,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">39/39</div></div></div>
# [34] 39/39 complete  (39 files found)
# Done — all 39 shots processed.

# %%
# scan 2D MOT X starting around 1.371. Scanning in HH configuration first to see if maximum shifted before making a gradient. 
#np.tile(np.arange(1.4, 1.6, 0.02), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 29,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [26] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
# scan 2D MOT Y starting around 1.09. Scanning in HH configuration first to see if maximum shifted before making a gradient. 
#np.tile(np.arange(0.8, 1.2, 0.02), 3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 30,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [41] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# imaging camera exposure duration to find opptimal 
#np.tile(np.arange(0.01, 0.05, 0.005),3)
scan_key = 'exposure_duration'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 39,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">24/24</div></div></div>
# [15] 24/24 complete  (24 files found)
# Done — all 24 shots processed.

# %%
# scan 2D MOT X starting around 1.507. Scanning in HH configuration first to see if maximum shifted before making a gradient. 
#np.tile(np.arange(1, 1.65, 0.05), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 102,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">39/39</div></div></div>
# [37] 39/39 complete  (39 files found)
# Done — all 39 shots processed.

# %%
# scan 2D MOT Y starting around 1.09. Scanning in HH configuration first to see if maximum shifted before making a gradient. 
#np.tile(np.arange(0.8, 1.2, 0.02), 3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 121,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [50] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# Going over more itterations now. Starting values were 1.4 on X and 0.978 on Y. 
# Scanning over broad range on both coils to see bigger effect. 
# Scan X coils np.tile(np.arange(0, 3, 0.25), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 128,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [25] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# Scan X coils np.tile(np.arange(0, 3, 0.5), 6)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 129,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [23] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# Scan X coils np.tile(np.arange(1, 2, 0.2), 6)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 130,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [27] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
# Scan X coils np.tile(np.arange(1.2, 1.5, 0.05), 6)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 131,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">42/42</div></div></div>
# [38] 42/42 complete  (42 files found)
# Done — all 42 shots processed.

# %%
# Scan Y coils np.tile(np.arange(0, 3, 0.25), 6)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 132,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">72/72</div></div></div>
# [50] 72/72 complete  (72 files found)
# Done — all 72 shots processed.

# %%
# Scan Y coils np.tile(np.arange(0, 1.25, 0.25), 8)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 133,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">40/40</div></div></div>
# [35] 40/40 complete  (40 files found)
# Done — all 40 shots processed.

# %%
# Scan Y coils np.tile(np.arange(0, 0.5, 0.05), 8)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 134,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">80/80</div></div></div>
# [59] 80/80 complete  (80 files found)
# Done — all 80 shots processed.

# %%
# Scan Y coils np.tile(np.arange(0.2, 0.4, 0.02), 8)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 135,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">80/80</div></div></div>
# [56] 80/80 complete  (80 files found)
# Done — all 80 shots processed.

# %%
#Re-aligned x retro beam
# Scan Y coils np.tile(np.arange(0, 3, 0.25), 6)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 165,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">72/72</div></div></div>
# [51] 72/72 complete  (72 files found)
# Done — all 72 shots processed.

# %%
# Scan X coils np.tile(np.arange(0, 3, 0.25), 6)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 166,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">72/72</div></div></div>
# [56] 72/72 complete  (72 files found)
# Done — all 72 shots processed.

# %%
# Scan Y coils np.tile(np.arange(0, 3, 0.25), 3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 19, 'cs_mot_healthcheck', 167,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [33] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# Out:
# 1.240859561866434

# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

shot = hf.load_shot(2026, 9, 11, 'cs_molasses_healthcheck', 1)
# Out:
# C:\Users\lics\lics-codebase\labscript-suite\lyse\lyse\__init__.py:59: FutureWarning: Running standalone single-shot lyse scripts is deprecated. If you need this feature, let the developers know so it is not removed.
#   warnings.warn("Running standalone single-shot lyse scripts is deprecated. "

# %%
for key in shot.keys():
    print(key)
# Out:
# Aerotech_Control_background
# BFL_AO_Sw_background
# BFL_Int_Lock_background
# Bias_X_AH_CsCMOT
# Bias_X_AH_CsMOT
# Bias_X_AH_Molasses
# Bias_X_AH_background
# Bias_X_HH_CsCMOT
# Bias_X_HH_CsMOT
# Bias_X_HH_Molasses
# Bias_X_HH_background
# Bias_Y_AH_CsCMOT
# Bias_Y_AH_CsMOT
# Bias_Y_AH_Molasses
# Bias_Y_AH_background
# Bias_Y_HH_CsCMOT
# Bias_Y_HH_CsMOT
# Bias_Y_HH_Molasses
# Bias_Y_HH_background
# Bias_Z_AH_CsCMOT
# Bias_Z_AH_CsMOT
# Bias_Z_AH_Molasses
# Bias_Z_AH_background
# Bias_Z_HH_CsCMOT
# Bias_Z_HH_CsMOT
# Bias_Z_HH_Molasses
# Bias_Z_HH_background
# Bitter_AH_Upper_FF_background
# Bitter_HH_Upper_FF_CsMOT
# Bitter_HH_Upper_FF_background
# Bitter_IServo_FB_Sw_CsMOT
# Bitter_IServo_FB_Sw_background
# Bitter_Lower_CC_CsMOT
# Bitter_Lower_CC_background
# Bitter_Lower_CV_CsMOT
# Bitter_Lower_CV_background
# Bitter_Lower_FF_CsMOT
# Bitter_Lower_FF_background
# Bitter_Upper_AH_Sw_background
# Bitter_Upper_CC_CsMOT
# Bitter_Upper_CC_backgound
# Bitter_Upper_CV_CsMOT
# ...

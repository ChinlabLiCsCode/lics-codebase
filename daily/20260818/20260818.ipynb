# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

# scan MOT loading time
scan_key = 'Cs_MOT_Load_Time'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 2,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'exponential'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [1] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X minus plugged in positively and X plus negatively
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 5,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">87/87</div></div></div>
# [45] 87/87 complete  (87 files found)
# Done — all 87 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X minus plugged in negatively now
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 6,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">42/42</div></div></div>
# [37] 42/42 complete  (42 files found)
# Done — all 42 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with Y minus plugged in positively
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 7,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">42/42</div></div></div>
# [18] 42/42 complete  (42 files found)
# Done — all 42 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with Y minus plugged in positively
scan_key = 'TOF_Time'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 82,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'), ('absorption_image_analysis', 'sigma_x (um)'), ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">57/57</div></div></div>
# [48] 57/57 complete  (57 files found)
# Done — all 57 shots processed.

# %%
importlib.reload(hf)

# Sequence 18 is already complete — load directly instead of polling
df_tof = hf.load_scan(2026, 8, 18, 'cs_mot_healthcheck', 82)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'ballistic',
          ('sigma_y (um)', 'TOF_Time'): 'ballistic',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')

# Note: seq 18 was taken before the magnification was recalibrated to 1.2818.
# Re-run lyse on these shots, or apply cal['temp_scale'] correction if needed.
# Out:
# T_x = 99.6 μK,  T_y = 99.1 μK,  g = -7.329 m/s²

# %%
importlib.reload(hf)

# Sequence 18 is already complete — load directly instead of polling
df_tof = hf.load_scan(2026, 8, 18, 'cs_mot_healthcheck', 83)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'ballistic',
          ('sigma_y (um)', 'TOF_Time'): 'ballistic',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')

# Note: seq 18 was taken before the magnification was recalibrated to 1.2818.
# Re-run lyse on these shots, or apply cal['temp_scale'] correction if needed.
# Out:
# T_x = 112.2 μK,  T_y = 96.8 μK,  g = -8.046 m/s²

# %%
# scan 2D MOT X coil values in HH configuration with Y minus plugged in positively
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 84,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">90/90</div></div></div>
# [1] 90/90 complete  (90 files found)
# Done — all 90 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with Y minus plugged in positively
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 85,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">90/90</div></div></div>
# [56] 90/90 complete  (90 files found)
# Done — all 90 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with Y minus plugged in positively
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 87,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">90/90</div></div></div>
# [56] 90/90 complete  (90 files found)
# Done — all 90 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X minus plugged in negatively
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 88,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [30] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X minus plugged in negatively
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 89,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [1] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X minus plugged in negatively
# Flipped the x beam QWP by 90 deg
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 90,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [36] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X minus plugged in negatively
# Flipped the x beam QWP by 45 deg
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 91,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [1] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X plus plugged in negatively
# Re-did polarization to check it was circular and placed QWP after the EO3. 
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 92,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [32] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X coil values in HH configuration with X plus plugged in positively
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 93,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [38] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT Y coil values in HH configuration with Y plus plugged in negatively
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 94,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [33] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT Y coil values in HH configuration with Y plus plugged in positively
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 95,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [35] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT Y coil values in HH configuration with Y plus plugged in positively
# Re-did the Y path polarization to be circular
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 96,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [29] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT Y coil values in HH configuration with Y plus plugged in negatively
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 18, 'cs_mot_healthcheck', 97,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [38] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

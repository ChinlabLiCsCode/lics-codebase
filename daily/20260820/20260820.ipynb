# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

# scan 2D MOT X. Scanning in HH configuration first to see if maximum shifted before making a gradient. 
#np.tile(np.arange(0, 3, 0.25), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 20, 'cs_mot_healthcheck', 75,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [23] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X. 
#np.tile(np.arange(1, 2, 0.05), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 20, 'cs_mot_healthcheck', 76,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [52] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# scan 2D MOT Y. 
#np.tile(np.arange(0, 3, 0.25), 3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 20, 'cs_mot_healthcheck', 77,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [42] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT X with Y=1.656. 
#np.tile(np.arange(0, 3, 0.25), 3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 20, 'cs_mot_healthcheck', 78,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [38] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan 2D MOT Y with X=2.055. 
#np.tile(np.arange(0, 3, 0.25), 3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 20, 'cs_mot_healthcheck', 79,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [33] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

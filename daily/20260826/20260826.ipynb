# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib

# %% [markdown]
# TOF temperature measurement

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

#TOF_Time =  np.tile(np.arange(0.002, 0.02, 0.002), 3)
df_tof = hf.load_scan(2026, 8, 26, 'cs_molasses_healthcheck', 0)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'quadrature',
          ('sigma_y (um)', 'TOF_Time'): 'quadrature',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')
# Out:
# T_x = 35.8 μK,  T_y = 39.9 μK,  g = -9.768 m/s²

# %%
# scan of Cs_Rep_Freq_Molasses with these settings
# Cs_Rep_Freq_Molasses = np.tile(np.arange(6, 7, 0.05),3)

scan_key = 'Cs_Rep_Freq_Molasses'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 1,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [50] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# scan of Cs_MOT_Freq_Molasses with these settings
# Cs_MOT_Freq_Molasses = np.tile(np.arange(-7, -5, 0.1),3)

scan_key = 'Cs_MOT_Freq_Molasses'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 2,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:72%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">43/60</div></div></div>
# [137] 43/60 complete  (60 files found)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 # scan of Cs_MOT_Freq_Molasses with these settings
#       2 # Cs_MOT_Freq_Molasses = np.tile(np.arange(-7, -5, 0.1),3)
#       3
#       4 scan_key = 'Cs_MOT_Freq_Molasses'
# ----> 5 fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 2,
#       6     scan_keys=[scan_key],
#       7     result_keys=[
#       8         ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
#
# File ~\lics-codebase\analysislib\helperfuncs.py:455, in live_plot_scan(year, month, day, sequence, number, result_keys, n_shots, scan_keys, fits, poll_interval)
#     452     continue
#     454 try:
# --> 455     df = get_dataframe_from_shots(h5_files)
#     457     if n_shots is None:
#     458         try:
#
# File ~\lics-codebase\labscript-suite\lyse\lyse\dataframe_utilities.py:155, in get_dataframe_from_shots(filepaths)
#     154 def get_dataframe_from_shots(filepaths):
# --> 155     return concat_with_padding(*[get_dataframe_from_shot(filepath) for filepath in filepaths])
#
# File ~\lics-codebase\labscript-suite\lyse\lyse\dataframe_utilities.py:155, in <listcomp>(.0)
#     154 def get_dataframe_from_shots(filepaths):
# --> 155     return concat_with_padding(*[get_dataframe_from_shot(filepath) for filepath in filepaths])
#
# File ~\lics-codebase\labscript-suite\lyse\lyse\dataframe_utilities.py:149, in get_dataframe_from_shot(filepath)
#     148 def get_dataframe_from_shot(filepath):
# --> 149     nested_dict = get_nested_dict_from_shot(filepath)
#     150     flat_dict =  flatten_dict(nested_dict)
#     151     df = flat_dict_to_hierarchical_dataframe(flat_dict)
#
# File ~\lics-codebase\labscript-suite\lyse\lyse\dataframe_utilities.py:63, in get_nested_dict_from_shot(filepath)
#      62 def get_nested_dict_from_shot(filepath):
# ---> 63     row = get_shot_globals(filepath)
#      64     with h5py.File(filepath,'r') as h5_file:
#      65         if 'results' in h5_file:
#
# File ~\lics-codebase\labscript-suite\labscript-utils\labscript_utils\shot_utils.py:22, in get_shot_globals(filepath)
#      18 """Returns the evaluated globals for a shot, for use by labscript or lyse.
#      19 Simple dictionary access as in dict(h5py.File(filepath).attrs) would be fine
#      20 except we want to apply some hacks, so it's best to do that in one place."""
#      21 params = {}
# ---> 22 with h5py.File(filepath, 'r') as f:
#      23     for name, value in f['globals'].attrs.items():
#      24         # Convert numpy bools to normal bools:
#      25         if isinstance(value, np.bool_):
#
# File ~\lics-codebase\labscript-suite\labscript-utils\labscript_utils\h5_lock.py:84, in File.__exit__(self, *args)
#      66         self.kill_lock.release()
#      68 # Overriding __exit__ is crucial. Since h5py.File.__exit__() holds h5py's
#      69 # library-wide lock "phil", it calls close() whilst holding that lock. Our close()
#      70 # method does not need the lock (h5py.File.close() does, but it acquires it itself
#    (...)     82 # necessary. I will report this as an issue in h5py, and will remove this workaround
#      83 # if it is fixed in a future version.
# ---> 84 def __exit__(self, *args):
#      85     self.close()
#
# KeyboardInterrupt:

# %%
# scan of Cs_Rep_Freq_Molasses with these settings
# Cs_Rep_Freq_Molasses = np.tile(np.arange(6, 7, 0.05),3)

scan_key = 'Cs_Rep_Freq_Molasses'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 4,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [77] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# originally -5.8
scan_key = 'Cs_MOT_Freq_Molasses'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 5,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [43] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# originally 1.5
scan_key = 'Cs_3DMOT_AO_AM_Molasses'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 6,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [1] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# originally 0.06
# np.tile(np.arange(0, 0.15,0.01), 3)
scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 7,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [55] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

# %%
# originally 0.06
# np.tile(np.arange(0, 0.08,0.005), 3)
scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 9,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">48/48</div></div></div>
# [64] 48/48 complete  (48 files found)
# Done — all 48 shots processed.

# %%
# originally 0.06
# np.tile(np.arange(0, 3, 0.2), 3)
scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 26, 'cs_molasses_healthcheck', 10,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [77] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

#TOF_Time =  np.tile(np.arange(0.002, 0.02, 0.002), 3)
df_tof = hf.load_scan(2026, 8, 26, 'cs_molasses_healthcheck', 83)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'quadrature',
          ('sigma_y (um)', 'TOF_Time'): 'quadrature',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')
# Out:
# T_x = 41.4 μK,  T_y = 45.9 μK,  g = -9.422 m/s²

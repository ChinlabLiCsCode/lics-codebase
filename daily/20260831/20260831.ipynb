# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

#TOF_Time =  np.tile(np.arange(0.002, 0.025, 0.002), 3)
df_tof = hf.load_scan(2026, 8, 31, 'cs_molasses_healthcheck', 4)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'quadrature',
          ('sigma_y (um)', 'TOF_Time'): 'quadrature',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')
# Out:
# T_x = 1.3 μK,  T_y = 30.1 μK,  g = -11.236 m/s²

# %%
# scan of Cs_Molasses_Time with these settings
# Cs_Molasses_Time = np.tile(np.arange(0, 0.5, 0.04),3)

scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 31, 'cs_molasses_healthcheck', 5,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">39/39</div></div></div>
# [63] 39/39 complete  (39 files found)
# Done — all 39 shots processed.

# %%
# scan of Bias_X_AH_Molasses with these settings
# Bias_X_AH_Molasses = np.tile(np.arange(-3, 3, 0.5),3)

scan_key = 'Bias_X_AH_Molasses'
fig = hf.live_plot_scan(2026, 8, 31, 'cs_molasses_healthcheck', 6,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [71] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan of Bias_X_AH_Molasses with these settings
# Bias_X_AH_Molasses = np.tile(np.arange(0, 3, 0.5),3)

scan_key = 'Bias_X_AH_Molasses'
fig = hf.live_plot_scan(2026, 8, 31, 'cs_molasses_healthcheck', 7,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [85] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

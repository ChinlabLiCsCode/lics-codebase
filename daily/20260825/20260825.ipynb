# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib

# %% [markdown]
# # Time of flight temperature measurement of cs mot after molasses cooling:
#
# - 3 seconds of mot loading
# - 0.1 seconds of molasses time

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

#TOF_Time =  np.tile(np.arange(0.002, 0.02, 0.002), 3)
df_tof = hf.load_scan(2026, 8, 25, 'cs_molasses_healthcheck', 43)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'ballistic',
          ('sigma_y (um)', 'TOF_Time'): 'ballistic',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')
# Out:
# T_x = 38.5 μK,  T_y = 41.6 μK,  g = -9.249 m/s²

# %% [markdown]
# # Cs_2D MOT Coil Optimization, coarse scanning X coils in HH configuration

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

# Cs_2DMOT_X_minus_CsMOT = np.tile(np.arange(0,3,0.3),3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 45,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [54] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %% [markdown]
# # fine scan of x coils in hh configuration

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

# Cs_2DMOT_X_minus_CsMOT = np.tile(np.arange(1,2,0.1),3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 46,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [57] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

# Cs_2DMOT_X_minus_CsMOT = np.tile(np.arange(1,1.5,0.05),3)
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 47,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [55] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %% [markdown]
# # Cs_2D MOT Coil Optimization, coarse scanning Y coils in HH configuration

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

# Cs_2DMOT_Y_minus_CsMOT = np.tile(np.arange(0,3,0.3),3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 48,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [56] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %% [markdown]
# # fine scan of y coils in hh configuration

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

# Cs_2DMOT_Y_minus_CsMOT = np.tile(np.arange(1,2,0.1),3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 49,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [56] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

# Cs_2DMOT_Y_minus_CsMOT = np.tile(np.arange(0.6,1.4,0.05),3)
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 50,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">48/48</div></div></div>
# [38] 48/48 complete  (48 files found)
# Done — all 48 shots processed.

# %% [markdown]
# # scan 2D MOT X AH component

# %%
# Cs_2DMOT_X_minus_CsMOT = np.tile(np.arange(0, 2.5, 0.2), 3)
# Cs_2DMOT_X_plus_CsMOT = 2.6-Cs_2DMOT_X_minus_CsMOT
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 61,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">39/39</div></div></div>
# [36] 39/39 complete  (39 files found)
# Done — all 39 shots processed.

# %%
# Cs_2DMOT_Y_minus_CsMOT = np.tile(np.arange(0, 2, 0.2), 3)
# Cs_2DMOT_Y_plus_CsMOT = 2-Cs_2DMOT_Y_minus_CsMOT
scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 62,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [20] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
# rescan X HH around these settings
# Cs_2DMOT_X_minus_CsMOT = np.tile(np.arange(1.4, 3, 0.15), 3)
# Cs_2DMOT_X_plus_CsMOT = Cs_2DMOT_X_minus_CsMOT-1.4

scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 63,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [41] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
# Coarse scan of x HH with these settings
# Cs_2DMOT_X_minus_CsMOT = np.tile(np.arange(0, 3, 0.2), 3)
# Cs_2DMOT_X_plus_CsMOT = 3-Cs_2DMOT_X_minus_CsMOT

scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 64,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [1] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

# %%
# Coarse scan of Y HH with these settings
# Cs_2DMOT_Y_minus_CsMOT = np.tile(np.arange(0, 3, 0.2), 3)
# Cs_2DMOT_Y_plus_CsMOT = 3-Cs_2DMOT_Y_minus_CsMOT

scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 65,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [1] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

# %%
# fine scan of molasses time with these settings
# Cs_Molasses_Time = np.tile(np.arange(0, 1, 0.06), 3)

scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 77,
    scan_keys=[scan_key], 
    result_keys=[
            ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
              ('absorption_image_analysis', 'N_y'),
              ('absorption_image_analysis', 'sigma_x (um)'),
              ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
        ('rho_2d (atoms/um^2)', scan_key): 'gaussian',
        ('N_y', scan_key): 'gaussian',
        ('sigma_x (um)', scan_key): 'gaussian',
        ('sigma_y (um)', scan_key): 'gaussian'
        }
    )
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">51/51</div></div></div>
# [1] 51/51 complete  (51 files found)
# Done — all 51 shots processed.

# %%
# fine scan of molasses time with these settings
# Cs_Molasses_Time = np.tile(np.arange(0, 0.4, 0.02), 3)

scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 78,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'gaussian',
            ('N_y', scan_key): 'gaussian',
            ('sigma_x (um)', scan_key): 'gaussian',
            ('sigma_y (um)', scan_key): 'gaussian'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [1] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# scan of Bias_Y_HH with these settings
# Bias_Y_HH_Molasses = np.tile(np.arange(-4, 0, 0.2), 3)

scan_key = 'Bias_Y_HH_Molasses'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 80,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [1] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# fine scan of molasses time with these settings
# Cs_Molasses_Time = np.tile(np.arange(0, 0.4, 0.02), 3)

scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 81,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'gaussian',
            ('N_y', scan_key): 'gaussian',
            ('sigma_x (um)', scan_key): 'gaussian',
            ('sigma_y (um)', scan_key): 'gaussian'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [72] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# fine scan of molasses time with these settings
# Cs_Molasses_Time = np.tile(np.arange(0, 0.4, 0.02), 3)

scan_key = 'Cs_Molasses_Time'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 82,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'exponential',
            ('N_y', scan_key): 'exponential',
            ('sigma_x (um)', scan_key): 'exponential',
            ('sigma_y (um)', scan_key): 'exponential'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">60/60</div></div></div>
# [1] 60/60 complete  (60 files found)
# Done — all 60 shots processed.

# %%
# scan of Bias_X_HH with these settings
# Bias_X_HH_Molasses = np.tile(np.arange(0, 3, 0.2), 3)

scan_key = 'Bias_X_HH_Molasses'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 83,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [54] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

# %%
# scan of Bias_X_HH with these settings
# Bias_Z_HH_Molasses = np.tile(np.arange(-4, 2, 0.4), 3)

scan_key = 'Bias_Z_HH_Molasses'
fig = hf.live_plot_scan(2026, 8, 25, 'cs_molasses_healthcheck', 84,
    scan_keys=[scan_key], 
    result_keys=[
        ('absorption_image_analysis', 'rho_2d (atoms/um^2)'),
          ('absorption_image_analysis', 'N_y'),
          ('absorption_image_analysis', 'sigma_x (um)'),
          ('absorption_image_analysis', 'sigma_y (um)')],
    fits={
            ('rho_2d (atoms/um^2)', scan_key): 'quadratic',
            ('N_y', scan_key): 'quadratic',
            ('sigma_x (um)', scan_key): 'quadratic',
            ('sigma_y (um)', scan_key): 'quadratic'
            }
)
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">45/45</div></div></div>
# [25] 45/45 complete  (45 files found)
# Done — all 45 shots processed.

# %% [markdown]
# Tof temerature measurement using optimized values

# %%
import analysislib.helperfuncs as hf
importlib.reload(hf)

#TOF_Time =  np.tile(np.arange(0.002, 0.02, 0.002), 3)
df_tof = hf.load_scan(2026, 8, 25, 'cs_molasses_healthcheck', 87)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'ballistic',
          ('sigma_y (um)', 'TOF_Time'): 'ballistic',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')
# Out:
# T_x = 37.4 μK,  T_y = 41.7 μK,  g = -8.899 m/s²

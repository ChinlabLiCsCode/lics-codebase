# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

# scan 2D MOT X
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 21, 'cs_molasses_healthcheck', 64,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'quadratic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">57/57</div></div></div>
# [1] 57/57 complete  (57 files found)
# Done — all 57 shots processed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

# scan 2D MOT X. 
scan_key = 'Cs_2DMOT_X_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 21, 'cs_molasses_healthcheck', 65,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'cubic'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [1] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

scan_key = 'Cs_2DMOT_Y_minus_CsMOT'
fig = hf.live_plot_scan(2026, 8, 21, 'cs_molasses_healthcheck', 66,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_y')],
    fits={('N_y', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [18] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

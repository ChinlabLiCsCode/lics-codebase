# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

# scan Zeeman C2
# Zeeman_C2_CsMOT = 0.45 from old sequence, 0.40 from previous MLOOP
scan_key = 'Zeeman_C2_CsMOT'
# np.tile(np.arange(0, 0.8, 0.1), 4)
fig = hf.live_plot_scan(2026, 8, 17, 'cs_mot_healthcheck', 3,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">32/32</div></div></div>
# [1] 32/32 complete  (32 files found)
# Done — all 32 shots processed.

# %%
# scan Zeeman C2
# Zeeman_C2_CsMOT = 0.45 from old sequence, 0.40 from previous MLOOP
scan_key = 'Zeeman_C2_CsMOT'

fig = hf.live_plot_scan(2026, 8, 17, 'cs_mot_healthcheck', 4,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">48/48</div></div></div>
# [1] 48/48 complete  (48 files found)
# Done — all 48 shots processed.

# %%
# scan Zeeman C3
# Zeeman_C3_CsMOT = 0.2 from old sequence
scan_key = 'Zeeman_C3_CsMOT'

fig = hf.live_plot_scan(2026, 8, 17, 'cs_mot_healthcheck', 5,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">36/36</div></div></div>
# [1] 36/36 complete  (36 files found)
# Done — all 36 shots processed.

# %%
# scan Zeeman C4
# Zeeman_C4_CsMOT = 0.05 from old sequence
scan_key = 'Zeeman_C4_CsMOT'

fig = hf.live_plot_scan(2026, 8, 17, 'cs_mot_healthcheck', 6,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [1] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
# scan Zeeman C1
# Zeeman_C1_CsMOT = 0.0 from old sequence
scan_key = 'Zeeman_C1_CsMOT'

fig = hf.live_plot_scan(2026, 8, 17, 'cs_mot_healthcheck', 7,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [1] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
# scan Cs_MOT_Freq_CsMOT
# Cs_MOT_Freq_CsMOT = -7.21 from old sequence
scan_key = 'Cs_MOT_Freq_CsMOT'
np.tile(np.arange(-7.450, -7.050, 0.01), 4)
fig = hf.live_plot_scan(2026, 8, 17, 'cs_mot_healthcheck', 8,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int')],
    fits={('N_int', scan_key): 'gaussian'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">164/164</div></div></div>
# [1] 164/164 complete  (164 files found)
# Done — all 164 shots processed.

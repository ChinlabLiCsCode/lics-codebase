# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)

shot = hf.load_shot(2026, 8, 10, 'cs_mot_healthcheck', 37)
scan = hf.load_scan(2026, 8, 11, 'cs_mot_healthcheck', 2)
# print all keys

fig = hf.plot_scan(scan, 
    scan_keys=['Cs_MOT_Load_Time'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_x (um)')])
# Out:
# C:\Users\lics\lics-codebase\labscript-suite\lyse\lyse\__init__.py:59: FutureWarning: Running standalone single-shot lyse scripts is deprecated. If you need this feature, let the developers know so it is not removed.
#   warnings.warn("Running standalone single-shot lyse scripts is deprecated. "

# %%
importlib.reload(hf)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 6,
    scan_keys=['Cs_MOT_Load_Time'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits='exponential')
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">15/15</div></div></div>
# [1] 15/15 complete  (15 files found)
# Done — all 15 shots processed.

# %%
# scan cs imaging frequency
# Cs_MOT_Freq_CsLFHImg = -7.6535 initially
np.tile(np.arange(-7.657, -7.650, 0.0005), 3)
importlib.reload(hf)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 7,
    scan_keys=['Cs_MOT_Freq_CsLFHImg'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits='gaussian')
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">42/42</div></div></div>
# [25] 42/42 complete  (42 files found)
# Done — all 42 shots processed.

# %%
importlib.reload(hf)

# scan cs imaging frequency
# Cs_MOT_Freq_CsLFHImg = -7.6535 initially
np.tile(np.linspace(-7.69, -7.61, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 8,
    scan_keys=['Cs_MOT_Freq_CsLFHImg'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits='gaussian')
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [1] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan tof time for temperature
# TOF_Time = 0.010 initially
np.tile(np.linspace(0.010, 0.100, 10), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 9,
    scan_keys=['TOF_Time'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits='linear')
# note: this failed because bitter coil gradient was still on
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [26] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
# scan tof time for temperature
# TOF_Time = 0.010 initially
np.tile(np.linspace(0.010, 0.100, 10), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 14,
    scan_keys=['TOF_Time'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits='linear')
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">30/30</div></div></div>
# [28] 30/30 complete  (30 files found)
# Done — all 30 shots processed.

# %%
importlib.reload(hf)

# scan tof time for temperature
# TOF_Time = 0.010 initially
np.tile(np.linspace(0.010, 0.028, 8), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 18,
    scan_keys=['TOF_Time'], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', 'TOF_Time'): 'quadratic',
          ('x0_x (um)', 'TOF_Time'): 'quadratic',
          ('x0_y (um)', 'TOF_Time'): 'quadratic',
          ('sigma_x (um)', 'TOF_Time'): 'linear',
          ('sigma_y (um)', 'TOF_Time'): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">24/24</div></div></div>
# [1] 24/24 complete  (24 files found)
# Done — all 24 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 0.5, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 21,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'quadratic',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})

#note: range was not large enough to see any noticeable difference except maybe in the x position so increasing the range
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [1] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 1, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 22,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'quadratic',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [33] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 3, 21), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 27,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [1] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 3, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 30,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [32] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 3, 11), 10)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 31,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'quadratic',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">110/110</div></div></div>
# [1] 110/110 complete  (110 files found)
# Done — all 110 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 3, 11), 10)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 33,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">110/110</div></div></div>
# [8] 110/110 complete  (110 files found)
# Done — all 110 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(1, 2, 21), 5)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 34,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">105/105</div></div></div>
# [1] 105/105 complete  (105 files found)
# Done — all 105 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 3, 41), 8)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 36,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">328/328</div></div></div>
# [1] 328/328 complete  (328 files found)
# Done — all 328 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
np.tile(np.linspace(0, 3, 41), 8)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 38,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:54%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">176/328</div></div></div>
# [1] 176/328 complete  (328 files found)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 7
#       3 # scan 2D MOT coil x symmetric
#       4 # Cs_2DMOT_X_plus_CsMOT = 0 initially
#       5 scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
#       6 np.tile(np.linspace(0, 3, 41), 8)
# ----> 7 fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 38,
#       8     scan_keys=[scan_key],
#       9     result_keys=[('absorption_image_analysis', 'N_int'),
#      10                  ('absorption_image_analysis', 'x0_x (um)'),
#
# ...

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
np.tile(np.linspace(0, 3, 31), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 39,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">93/93</div></div></div>
# [72] 93/93 complete  (93 files found)
# Done — all 93 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_Y_plus_CsMOT'
np.tile(np.linspace(0, 3, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 40,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})

# This time I am scanning with Cs_2DMOT_X_plus_CsMOT = 3.0
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [9] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(1.5, 3, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 41,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})

# This time I am scanning with over a gradient in the X fields starting at 1.5 and going up in one coil and down in the other
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [13] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(0, 3, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 42,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})

# I flipped the X coils back to a AH configuration and ramped them up symmetrically
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [15] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# scan 2D MOT coil x symmetric 
# Cs_2DMOT_X_plus_CsMOT = 0 initially
scan_key = 'Cs_2DMOT_X_plus_CsMOT'
np.tile(np.linspace(1.5, 3, 11), 3)
fig = hf.live_plot_scan(2026, 8, 11, 'cs_mot_healthcheck', 43,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'N_int'),
                 ('absorption_image_analysis', 'x0_x (um)'),
                 ('absorption_image_analysis', 'x0_y (um)'),
                 ('absorption_image_analysis', 'sigma_x (um)'), 
                 ('absorption_image_analysis', 'sigma_y (um)')],
    fits={('N_int', scan_key): 'gaussian',
          ('x0_x (um)', scan_key): 'quadratic',
          ('x0_y (um)', scan_key): 'quadratic',
          ('sigma_x (um)', scan_key): 'linear',
          ('sigma_y (um)', scan_key): 'linear'})

# Now ramping them up as a gradient
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">33/33</div></div></div>
# [19] 33/33 complete  (33 files found)
# Done — all 33 shots processed.

# %%
importlib.reload(hf)

# Sequence 18 is already complete — load directly instead of polling
df_tof = hf.load_scan(2026, 8, 11, 'cs_mot_healthcheck', 18)

fig, fit_results = hf.plot_scan(df_tof,
    scan_keys=['TOF_Time'],
    result_keys=[('absorption_image_analysis', 'sigma_x (um)'),
                 ('absorption_image_analysis', 'sigma_y (um)'),
                 ('absorption_image_analysis', 'x0_y (um)')],
    fits={('sigma_x (um)', 'TOF_Time'): 'ballistic',
          ('sigma_y (um)', 'TOF_Time'): 'ballistic',
          ('x0_y (um)',    'TOF_Time'): 'quadratic'})

T_x = hf.tof_temperature(fit_results, 'sigma_x (um)')
T_y = hf.tof_temperature(fit_results, 'sigma_y (um)')
g   = hf.tof_gravity(fit_results, 'x0_y (um)')
print(f'T_x = {T_x*1e6:.1f} μK,  T_y = {T_y*1e6:.1f} μK,  g = {g:.3f} m/s²')

# Note: seq 18 was taken before the magnification was recalibrated to 1.2818.
# Re-run lyse on these shots, or apply cal['temp_scale'] correction if needed.
# Out:
# T_x = 97.7 μK,  T_y = 121.9 μK,  g = -10.475 m/s²
# T_x (corrected) = 85.6 μK
# T_y (corrected) = 106.8 μK

# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import analysislib.helperfuncs as hf
importlib.reload(hf)


# scanning pixelfly shutter opening time to make sure the shutter fully opens before the image

# pixelfly_shutter_open_offset is originally -0.008 but we definitely see the shutter 
# pixelfly_shutter_open_offset = np.arange(-0.020, 0.000, 0.0005)
scan_key = 'pixelfly_shutter_open_offset'
results, fig = hf.live_plot_scan(2026, 9, 4, 'cs_mot_healthcheck', 5,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'atoms_mean_counts'), 
    ('absorption_image_analysis', 'light_mean_counts'), 
    ('absorption_image_analysis', 'dark_mean_counts')])
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">40/40</div></div></div>
# [1] 40/40 complete  (40 files found)
# Done — all 40 shots processed.

# %%
# scanning pixelfly shutter closing time to make sure the shutter fully opens before the image

# pixelfly_shutter_close_offset is originally -0.001
# pixelfly_shutter_close_offset = np.arange(-0.009, 0.000, 0.0005)
scan_key = 'pixelfly_shutter_close_offset'
results, fig = hf.live_plot_scan(2026, 9, 4, 'cs_mot_healthcheck', 6,
    scan_keys=[scan_key], 
    result_keys=[('absorption_image_analysis', 'atoms_mean_counts'), 
    ('absorption_image_analysis', 'light_mean_counts'), 
    ('absorption_image_analysis', 'dark_mean_counts')])
# Out:
# <div style="margin:4px 0 8px"><div style="background:#ddd;border-radius:4px;height:22px"><div style="background:#4caf50;width:100%;height:22px;border-radius:4px;line-height:22px;color:#fff;text-align:center;font-size:13px">18/18</div></div></div>
# [16] 18/18 complete  (18 files found)
# Done — all 18 shots processed.
